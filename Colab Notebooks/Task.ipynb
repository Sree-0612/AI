# %% [markdown]
# #Sentence Tansformers

# %%
pip install sentence-transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 5.7 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %% [markdown]
# Generate Embeddings for 10 sentences

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

# Load a pre-trained Sentence Transformers model
model = SentenceTransformer('average_word_embeddings_glove.6B.300d')

sentences = [
    "The feedback tools and software are essential for any business that wants to understand and improve its customer relationships.",
    "They allow you to collect, analyze, and act on the feedback you receive from your customers, whether it's through surveys, reviews, ratings, or other channels.",
    "Customer Relationship Management is all about how businesses connect with their current and prospective customers to improve customer satisfaction and ensure a profitable sales cycle.",
    "User feedback is qualitative and quantitative data from customers on their likes, dislikes, impressions, and requests about a product.",
    "Collecting and making sense of user feedback is critical for businesses that wish to make improvements based on what their users need.",
    "Creating and managing campaigns, analyzing and reporting data, communicating and collaborating with customers and team members, or solving problems and resolving issues.",
    "It is a technology for managing all of your company's interactions with current and potential customers. The goal is simple: improve relationships to grow your business.",
    "CRM also uses data and insights analysis to continuously improve the customer experience to increase the customer lifetime value (LTV), and decrease the costs of marketing, and mining new customers.",
    "CRM skills are the various managerial skills that can enable customer relations managers (or customer relationships managers) to promote commercial brands and build lasting relationships with target customers.",
    "By intelligently storing and managing your customers' information, a CRM system increases the number of leads coming in, helping your marketing team find new customers faster. It supports your sales teams in closing more deals faster. It also enhances customer service."
]

# Generate embeddings for each sentence
sentence_embeddings = [model.encode(sentence) for sentence in sentences]

# Print the embeddings
for index, embedding in enumerate(sentence_embeddings):
    print(f"Sentence {index+1} embedding: {embedding}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/248 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# ...

# %% [markdown]
# #Task

# %%
from sentence_transformers import SentenceTransformer
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Load a pre-trained Sentence Transformers model
model = SentenceTransformer('average_word_embeddings_glove.6B.300d')

# %%
# Define the sentences
sentences = [
    "The feedback tools and software are essential for any business that wants to understand and improve its customer relationships.",
    "They allow you to collect, analyze, and act on the feedback you receive from your customers, whether it's through surveys, reviews, ratings, or other channels.",
    "Customer Relationship Management is all about how businesses connect with their current and prospective customers to improve customer satisfaction and ensure a profitable sales cycle.",
    "User feedback is qualitative and quantitative data from customers on their likes, dislikes, impressions, and requests about a product.",
    "Collecting and making sense of user feedback is critical for businesses that wish to make improvements based on what their users need.",
    "Creating and managing campaigns, analyzing and reporting data, communicating and collaborating with customers and team members, or solving problems and resolving issues.",
    "It is a technology for managing all of your company's interactions with current and potential customers. The goal is simple: improve relationships to grow your business.",
    "CRM also uses data and insights analysis to continuously improve the customer experience to increase the customer lifetime value (LTV), and decrease the costs of marketing, and mining new customers.",
    "CRM skills are the various managerial skills that can enable customer relations managers (or customer relationships managers) to promote commercial brands and build lasting relationships with target customers.",
    "By intelligently storing and managing your customers' information, a CRM system increases the number of leads coming in, helping your marketing team find new customers faster. It supports your sales teams in closing more deals faster. It also enhances customer service."
]

# %%
# Encode the existing sentences
sentence_embeddings = [model.encode(sentence) for sentence in sentences]

# %%
# Define the new sentence
new_sentence = "this is an apple"

# %%
# Encode the new sentence
new_sentence_embedding = model.encode(new_sentence)

# Compute cosine similarity between the new sentence and the existing sentences
cosine_similarities = cosine_similarity(np.array(sentence_embeddings), np.array([new_sentence_embedding]))

# Find the maximum similarity score
max_similarity = np.max(cosine_similarities)

# Set a threshold for significant similarity
threshold = 0.7

# %%
# Check if the maximum similarity score exceeds the threshold
if max_similarity > threshold:
    print("This statement is related to the first 10 statements")
else:
    print("This statement is not related to the first 10 statements")
# Out:
# This statement is not related to the first 10 statements

# %% [markdown]
# #new

# %%
pip install nltk

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
import nltk
from nltk.corpus import wordnet

def generate_similar_words(word):
    similar_words = []
    synsets = wordnet.synsets(word)
    for synset in synsets:
        for lemma in synset.lemmas():
            similar_words.append(lemma.name())
    return similar_words

word = "business"
similar_words = generate_similar_words(word)
print(similar_words)
# Out:
# ['business', 'concern', 'business_concern', 'business_organization', 'business_organisation', 'commercial_enterprise', 'business_enterprise', 'business', 'occupation', 'business', 'job', 'line_of_work', 'line', 'business', 'business', 'business', 'business', 'business_sector', 'clientele', 'patronage', 'business', 'business', 'stage_business', 'byplay']

# %% [markdown]
# new2

# %%
# Define the text
text = "Zoho CRM is a powerful tool that revolutionizes the way businesses manage their relationships with customers. It provides a comprehensive suite of features that allow businesses to track sales, automate marketing activities, and create custom reports. The intuitive interface of Zoho CRM makes it user-friendly, while its extensive features cater to the needs of businesses of all sizes. Whether it’s managing customer information, tracking sales history, or automating marketing activities, Zoho CRM has got it all covered. It’s not just a CRM tool, but a complete solution that empowers businesses to make data-driven decisions and achieve their sales goals.It is an exceptional email service that is clean, fast, and offers a user-friendly interface. Zoho mail provides a reliable and secure way for businesses to communicate internally and externally. With its powerful features such as instant chat, calendar, tasks, notes, and bookmarks, Zoho Mail goes beyond being just an email service and serves as a comprehensive communication hub. It also offers seamless integration with other Zoho applications, making it a perfect choice for businesses that use Zoho suite of products.Zoho Docs is a comprehensive online document management system used for storing, sharing, and managing files securely. It allows businesses to create, collaborate, and edit documents in real-time, making it an ideal tool for team collaboration. With its intuitive interface and robust features, Zoho Docs simplifies the process of managing and organizing files. It supports various file formats and allows users to upload and share files with ease. Its integration with other Zoho products and third-party applications enhances its functionality and makes it a versatile tool for businesses.Zoho Books is a comprehensive accounting solution designed to help businesses manage their finances and cash flow with ease. It offers a range of features including invoicing, expense tracking, inventory management, and sales and purchase order management. With its intuitive interface and powerful capabilities, Zoho Books simplifies the complex process of managing business finances, making it an ideal choice for small to medium-sized businesses."
# Define the product names
products = ["Zoho CRM", "Zoho Mail", "Zoho Docs", "Zoho Books"]

# Initialize a dictionary to hold the sentences for each product
product_sentences = {product: "" for product in products}

# Split the text for each product
for i in range(len(products)):
    # If it's the last product, take all the remaining text
    if i == len(products) - 1:
        product_sentences[products[i]] = text.split(products[i])[1].strip()
    else:
        # Split the text into two parts at the first occurrence of the next product name
        part1, part2 = text.split(products[i + 1], 1)
        # The sentences for the current product are the part after the current product name and before the next product name
        product_sentences[products[i]] = part1.split(products[i])[1].strip()
        # The remaining text is the part after the next product name
        text = products[i + 1] + part2

# Print the sentences for each product
for product, sentences in product_sentences.items():
    print(f"Sentences related to {product}:")
    print(sentences)
    print("\\n")
# Out:
# Sentences related to Zoho CRM:
# is a powerful tool that revolutionizes the way businesses manage their relationships with customers. It provides a comprehensive suite of features that allow businesses to track sales, automate marketing activities, and create custom reports. The intuitive interface of
# \n
# Sentences related to Zoho Mail:
# goes beyond being just an email service and serves as a comprehensive communication hub. It also offers seamless integration with other Zoho applications, making it a perfect choice for businesses that use Zoho suite of products.
# \n
# Sentences related to Zoho Docs:
# is a comprehensive online document management system used for storing, sharing, and managing files securely. It allows businesses to create, collaborate, and edit documents in real-time, making it an ideal tool for team collaboration. With its intuitive interface and robust features,
# \n
# Sentences related to Zoho Books:
# ...

# %% [markdown]
# NEWW

# %%
# !pip install sentence-transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 3.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from sentence_transformers import SentenceTransformer,util
model = SentenceTransformer('all-MiniLM-L6-v2')
from sklearn.cluster import KMeans
import numpy as np

embedder = SentenceTransformer('all-MiniLM-L6-v2')

# Corpus with example sentences
corpus = ["Zoho CRM is a powerful tool that revolutionizes the way businesses manage their relationships with customers. It provides a comprehensive suite of features that allow businesses to track sales, automate marketing activities, and create custom reports. The intuitive interface of Zoho CRM makes it user-friendly, while its extensive features cater to the needs of businesses of all sizes. Whether it’s managing customer information, tracking sales history, or automating marketing activities, Zoho CRM has got it all covered. It’s not just a CRM tool, but a complete solution that empowers businesses to make data-driven decisions and achieve their sales goals.It is an exceptional email service that is clean, fast, and offers a user-friendly interface. Zoho mail provides a reliable and secure way for businesses to communicate internally and externally. With its powerful features such as instant chat, calendar, tasks, notes, and bookmarks, Zoho Mail goes beyond being just an email service and serves as a comprehensive communication hub. It also offers seamless integration with other Zoho applications, making it a perfect choice for businesses that use Zoho suite of products.Zoho Docs is a comprehensive online document management system used for storing, sharing, and managing files securely. It allows businesses to create, collaborate, and edit documents in real-time, making it an ideal tool for team collaboration. With its intuitive interface and robust features, Zoho Docs simplifies the process of managing and organizing files. It supports various file formats and allows users to upload and share files with ease. Its integration with other Zoho products and third-party applications enhances its functionality and makes it a versatile tool for businesses.Zoho Books is a comprehensive accounting solution designed to help businesses manage their finances and cash flow with ease. It offers a range of features including invoicing, expense tracking, inventory management, and sales and purchase order management. With its intuitive interface and powerful capabilities, Zoho Books simplifies the complex process of managing business finances, making it an ideal choice for small to medium-sized businesses."]

corpus_embeddings = embedder.encode(corpus)
corpus_embeddings = corpus_embeddings /  np.linalg.norm(corpus_embeddings, axis=1, keepdims=True)

# %%
corpus_embeddings[0]
# Out:
# array([-7.69816041e-02,  2.78772321e-02, -2.36394759e-02,  3.64345573e-02,
#         3.77758257e-02, -3.62048596e-02,  3.94392610e-02,  3.95025611e-02,
#        -2.66848598e-02, -1.93365682e-02, -7.64941704e-03,  7.14560552e-03,
#         5.77145591e-02,  5.08444458e-02,  3.99094224e-02,  3.27236764e-03,
#         5.75791001e-02, -1.05352066e-01,  7.54874805e-03, -1.48548582e-03,
#        -2.26322860e-02,  2.89537292e-02,  2.84531638e-02,  3.95851582e-02,
#        -9.05193537e-02, -6.54558418e-03, -5.26798032e-02,  4.12280522e-02,
#        -5.59759587e-02, -1.64624713e-02,  1.64361354e-02,  4.91198674e-02,
#         7.85316527e-02,  4.14328501e-02, -6.60308078e-02, -1.33502632e-02,
#         7.21099004e-02,  9.39881895e-03, -1.62293687e-02, -2.54519545e-02,
#        -2.20569894e-02,  1.12927344e-03, -6.59530312e-02, -1.72802266e-02,
#         5.61426505e-02,  2.35443432e-02, -3.46775400e-03,  1.49986353e-02,
# ...

# %%
clustering_model = KMeans(n_clusters=5)
clustering_model.fit(corpus_embeddings)
cluster_assignment = clustering_model.labels_
print(cluster_assignment)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-92468114181a> in <cell line: 2>()
#       1 clustering_model = KMeans(n_clusters=5)
# ----> 2 clustering_model.fit(corpus_embeddings)
#       3 cluster_assignment = clustering_model.labels_
#       4 print(cluster_assignment)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#    1424         )
#    1425
# -> 1426         self._check_params_vs_input(X)
#    1427
#    1428         random_state = check_random_state(self.random_state)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py in _check_params_vs_input(self, X)
#    1360
#    1361     def _check_params_vs_input(self, X):
# -> 1362         super()._check_params_vs_input(X, default_n_init=10)
#    1363
#    1364         self._algorithm = self.algorithm
#
# ...

# %%
from sentence_transformers import SentenceTransformer, util
from sklearn.cluster import KMeans
import numpy as np
import nltk

# Download the Punkt tokenizer for sentence splitting
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    nltk.download('punkt')

# Corpus with example sentences
corpus_text = "Zoho CRM is a powerful tool that revolutionizes the way businesses manage their relationships with customers. It provides a comprehensive suite of features that allow businesses to track sales, automate marketing activities, and create custom reports. It is an exceptional email service that is clean, fast, and offers a user-friendly interface. Zoho mail provides a reliable and secure way for businesses to communicate internally and externally. With its powerful features such as instant chat, calendar, tasks, notes, and bookmarks, Zoho Mail goes beyond being just an email service and serves as a comprehensive communication hub. Zoho Docs is a comprehensive online document management system used for storing, sharing, and managing files securely. It allows businesses to create, collaborate, and edit documents in real-time, making it an ideal tool for team collaboration. Zoho Books is a comprehensive accounting solution designed to help businesses manage their finances and cash flow with ease. It offers a range of features including invoicing, expense tracking, inventory management, and sales and purchase order management. With its intuitive interface and powerful capabilities, Zoho Books simplifies the complex process of managing business finances, making it an ideal choice for small to medium-sized businesses."

# Split the corpus text into sentences
corpus = nltk.sent_tokenize(corpus_text)
print(corpus)

embedder = SentenceTransformer('all-MiniLM-L6-v2')

# Compute embeddings for each sentence in the corpus
corpus_embeddings = embedder.encode(corpus)
corpus_embeddings = corpus_embeddings /  np.linalg.norm(corpus_embeddings, axis=1, keepdims=True)

# Perform kmeans clustering
num_clusters = 4
clustering_model = KMeans(n_clusters=num_clusters)
clustering_model.fit(corpus_embeddings)
cluster_assignment = clustering_model.labels_

# Assign each sentence to a cluster
clustered_sentences = [[] for _ in range(num_clusters)]
for sentence_id, cluster_id in enumerate(cluster_assignment):
    clustered_sentences[cluster_id].append(corpus[sentence_id])

# Print clustered sentences
for i, cluster in enumerate(clustered_sentences):
    print(f"Cluster {i+1}:")
    print(cluster)
    print("\n")
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ...

# %%
clustered_sentences = {}
for sentence_id, cluster_id in enumerate(cluster_assignment):
    if cluster_id not in clustered_sentences:
        clustered_sentences[cluster_id] = []

    clustered_sentences[cluster_id].append(corpus[sentence_id])
clustered_sentences
# Out:
# {2: ['Zoho CRM is a powerful tool that revolutionizes the way businesses manage their relationships with customers.',
#   'Zoho Docs is a comprehensive online document management system used for storing, sharing, and managing files securely.',
#   'Zoho Books is a comprehensive accounting solution designed to help businesses manage their finances and cash flow with ease.',
#   'With its intuitive interface and powerful capabilities, Zoho Books simplifies the complex process of managing business finances, making it an ideal choice for small to medium-sized businesses.'],
#  1: ['It provides a comprehensive suite of features that allow businesses to track sales, automate marketing activities, and create custom reports.',
#   'It offers a range of features including invoicing, expense tracking, inventory management, and sales and purchase order management.'],
#  0: ['It is an exceptional email service that is clean, fast, and offers a user-friendly interface.',
# ...
